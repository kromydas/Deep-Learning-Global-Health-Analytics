# %%
# Import module that contains several convenience functions (e.g., gdal wrappers)
from gist_utils import *

# Adding path to gdal commands for local system
os.environ['PATH'] += ':/Users/billk/miniforge3/envs/py39-pt/bin/'

# %%
country_code = 'PK'

# %% [markdown]
# # AOI Processing (Nighlights)

# %%
data_type = 'Nightlights'
file_path_pattern = f'./{data_type}/output/{country_code}/*.tif'

stats_table = load_and_plot_geotiffs(file_path_pattern, plot_data=True, plot_geo_coords=False, clip_percentile=2)
print(stats_table)
# Out:
# NoData value for ./Nightlights/output/PK/N_VNL_v22_npp-j01_2022_global_vcmslcfg_median_PK_1_crop_geo.tif: None
# /Users/billk/dev/BMGF/Prithvi-Fine-Tuned-Global-Health/GIS-Image-Stack-Processing/gist_utils/gist_utils.py:1350: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   stats_df = pd.concat([stats_df, pd.DataFrame([new_row])], ignore_index=True)
# NoData value for ./Nightlights/output/PK/N_VNL_v22_npp-j01_2022_global_vcmslcfg_median_PK_2_nodata.tif: -999.0
# NoData value for ./Nightlights/output/PK/N_VNL_v22_npp-j01_2022_global_vcmslcfg_median_PK_3_crs.tif: -999.0
# NoData value for ./Nightlights/output/PK/N_VNL_v22_npp-j01_2022_global_vcmslcfg_median_PK_4_resampled_bilinear.tif: -999.0
# ...

# %% [markdown]
# # AOI Processing (Population)

# %%
data_type = 'Population'
file_path_pattern = f'./{data_type}/output/{country_code}/*.tif'

stats_table = load_and_plot_geotiffs(file_path_pattern, plot_data=True, plot_geo_coords=False, clip_percentile=1)
print(stats_table)
# Out:
# NoData value for ./Population/output/PK/P_landscan-global-2022_PK_1_crop_geo.tif: -2147483647.0
# /Users/billk/dev/BMGF/Prithvi-Fine-Tuned-Global-Health/GIS-Image-Stack-Processing/gist_utils/gist_utils.py:1350: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   stats_df = pd.concat([stats_df, pd.DataFrame([new_row])], ignore_index=True)
# NoData value for ./Population/output/PK/P_landscan-global-2022_PK_2_nodata.tif: -999.0
# NoData value for ./Population/output/PK/P_landscan-global-2022_PK_3_crs.tif: -999.0
# NoData value for ./Population/output/PK/P_landscan-global-2022_PK_4_resampled_nearest.tif: -999.0
# NoData value for ./Population/output/PK/population_1 temp.tif: None
# ...

# %% [markdown]
# # AOI Processing (Rainfall)

# %%
data_type = 'Rainfall'
file_path_pattern = f'./{data_type}/output/{country_code}/*.tif'

stats_table = load_and_plot_geotiffs(file_path_pattern, plot_data=True, plot_geo_coords=False, clip_percentile=0)
print(stats_table)
# Out:
# NoData value for ./Rainfall/output/PK/R_GPM_2001-2022.01.V07B_PK_avg_PK_1_crop_geo.tif: -999.0
# /Users/billk/dev/BMGF/Prithvi-Fine-Tuned-Global-Health/GIS-Image-Stack-Processing/gist_utils/gist_utils.py:1350: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   stats_df = pd.concat([stats_df, pd.DataFrame([new_row])], ignore_index=True)
# NoData value for ./Rainfall/output/PK/R_GPM_2001-2022.01.V07B_PK_avg_PK_2_nodata.tif: -999.0
# NoData value for ./Rainfall/output/PK/R_GPM_2001-2022.01.V07B_PK_avg_PK_3_crs.tif: -999.0
# NoData value for ./Rainfall/output/PK/R_GPM_2001-2022.01.V07B_PK_avg_PK_4_resampled_bilinear.tif: -999.0
#          File       Min       Max      Mean    Median NoData Count  \
# ...
